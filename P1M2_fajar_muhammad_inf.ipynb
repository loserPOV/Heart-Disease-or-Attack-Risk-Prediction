# %%
# import libraries
import pickle
import pandas as pd
import numpy as np

# %%
# load model
with open("model.pkl", "rb") as f:
    model = pickle.load(f)

# %%
# Membuat data dummy
data_inf = {
    'HighBP' : np.random.randint(0,2,5),
    'BMI' : np.random.randint(12,99,5),
    'HighChol' : np.random.randint(0,2,5),
    'Smoker' : np.random.randint(0,2,5),
    'Stroke' : np.random.randint(0,2,5),
    'Diabetes' : np.random.randint(0,3,5),
    'GenHlth' : np.random.randint(1,6,5),
    'DiffWalk' : np.random.randint(0,2,5),
    'Age' : np.random.randint(1,14,5),
    'Income' : np.random.randint(1,7,5),
    'PhysHlth' : np.random.randint(0,31,5)
}

data_inf = pd.DataFrame(data_inf)

# %%
prediction = model.predict(data_inf)
prediction = pd.DataFrame(prediction)

# %%
data_inf['Prediction'] = prediction
data_inf
# Out:
#    HighBP  BMI  HighChol  Smoker  Stroke  Diabetes  GenHlth  DiffWalk  Age  \
# 0       1   84         1       1       1         0        1         0   12
# 1       1   98         1       0       0         2        4         0    9
# 2       0   39         1       0       0         2        3         1   11
# 3       0   24         0       0       1         0        4         0    6
# 4       0   15         0       1       0         2        1         0    9
#
#    Income  PhysHlth  Prediction
# 0       1        29           1
# 1       3        24           1
# 2       6        28           1
# 3       4         2           1
# 4       5         2           1
